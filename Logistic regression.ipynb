# %% [markdown]
# ## Algerian Forest Fires Dataset Data Set
#
# Data Set Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012) Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
#
# FWI Components
#
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and Not Fire

# %%
#Importing liabraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Loading Dataset and assigning in to df as dataframe
df=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv", skipinitialspace=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 242  6.5       fire
# 243    0   not fire
# 244  0.2   not fire
# 245  0.7   not fire
# 246  0.5  not fire

# %% [markdown]
# #### We need to replace 122,123,124 column, these column have NAN and not correct value

# %%
df.loc[120:130]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 120                             29      9  2012           26   80   16    1.8
# 121                             30      9  2012           25   78   14    1.4
# 122                            NaN    NaN   NaN          NaN  NaN  NaN    NaN
# 123  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 124                            day  month  year  Temperature   RH   Ws  Rain
# 125                              1      6  2012           32   71   12    0.7
# 126                              2      6  2012           30   73   13      4
# 127                              3      6  2012           29   80   14      2
# 128                              4      6  2012           30   64   14      0
# 129                              5      6  2012           32   60   14    0.2
# 130                              6      6  2012           35   54   11    0.1
#
# ...

# %%
#Removing columns
df.drop([122,123,124], inplace=True)
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)

# %%
df.loc[120:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 122   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 123   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 124   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 125   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 126   5     6  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 127   6     6  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 128   7     6  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
# 129   8     6  2012          28  51  17   1.3  71.4  7.7   7.4  1.5   7.3
# 130   9     6  2012          27  59  18   0.1  78.1  8.5  14.7  2.4   8.3
#
#      FWI    Classes
# 120  0.1  not fire
# 121  0.1  not fire
# ...

# %% [markdown]
# #### There is 2 types of dataset Bejaia Region Dataset & Sidi-Bel Abbes Region Dataset now puting value as 0 for Bejaia Region Dataset and 1 for Sidi-Bel Abbes Region Dataset

# %%
df.loc[:121,'region'] = 0 # Bejaia Region Dataset 
df.loc[121:,'region'] = 1 # Sidi-Bel Abbes Region Dataset

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    region
# 239  6.5       fire        1.0
# 240    0   not fire        1.0
# 241  0.2   not fire        1.0
# 242  0.7   not fire        1.0
# 243  0.5  not fire         1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4   RH           244 non-null    object
#  5   Ws           244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  region       244 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 28.7+ KB

# %% [markdown]
# #### All the column datatype are object and column name have space, Now remioving column space and changing datatype as data

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'region'],
#       dtype='object')

# %%
#removing space from column 
df.columns=[i.strip() for i in df.columns]
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
# Removing space in columns
for features in ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']:
    df[features]=df[features].str.replace(" ","")

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# region         0
# dtype: int64

# %% [markdown]
# #### We have one null values available in dataset, Removing null values from dataset

# %%
df.loc[160:170]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC     DC   ISI   BUI  \
# 160   9     7  2012          36  43  15  1.9  82.3   9.4    9.9   3.2     9
# 161  10     7  2012          34  51  16  3.8  77.5     8    9.5     2   7.7
# 162  11     7  2012          34  56  15  2.9  74.8   7.1    9.5   1.6   6.8
# 163  12     7  2012          36  44  13    0  90.1  12.6   19.4   8.3  12.5
# 164  13     7  2012          39  45  13  0.6  85.2  11.3   10.4   4.2  10.9
# 165  14     7  2012          37  37  18  0.2  88.9  12.9  14.69  12.5  10.4
# 166  15     7  2012          34  45  17    0  90.5    18   24.1  10.9  17.7
# 167  16     7  2012          31  83  17    0  84.5  19.4   33.1   4.7  19.2
# 168  17     7  2012          32  81  17    0  84.6  21.1   42.3   4.7  20.9
# 169  18     7  2012          33  68  15    0  86.1  23.9   51.6   5.2  23.9
# 170  19     7  2012          34  58  16    0  88.1  27.8   61.1   7.3  27.7
#
#       FWI  Classes  region
# 160   3.1     fire     1.0
# ...

# %% [markdown]
# ##### Row no 165 have NaN value and incorrect value for FWI,  Fire Weather Index (FWI) Index: 0 to 31.1

# %%
#Removiving nan row and incorrect values
df.drop([165], inplace=True)
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)
df.loc[160:170]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC    DC   ISI   BUI  \
# 160   9     7  2012          36  43  15  1.9  82.3   9.4   9.9   3.2     9
# 161  10     7  2012          34  51  16  3.8  77.5     8   9.5     2   7.7
# 162  11     7  2012          34  56  15  2.9  74.8   7.1   9.5   1.6   6.8
# 163  12     7  2012          36  44  13    0  90.1  12.6  19.4   8.3  12.5
# 164  13     7  2012          39  45  13  0.6  85.2  11.3  10.4   4.2  10.9
# 165  15     7  2012          34  45  17    0  90.5    18  24.1  10.9  17.7
# 166  16     7  2012          31  83  17    0  84.5  19.4  33.1   4.7  19.2
# 167  17     7  2012          32  81  17    0  84.6  21.1  42.3   4.7  20.9
# 168  18     7  2012          33  68  15    0  86.1  23.9  51.6   5.2  23.9
# 169  19     7  2012          34  58  16    0  88.1  27.8  61.1   7.3  27.7
# 170  20     7  2012          36  50  16    0  89.9  32.7    71   9.5  32.6
#
#       FWI  Classes  region
# 160   3.1     fire     1.0
# ...

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# region         0
# dtype: int64

# %% [markdown]
# #### No Null values present in dataset

# %% [markdown]
# ### Changing datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  region       243 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 28.6+ KB

# %%
df['day']=df['day'].astype(int)
df['month']=df['month'].astype(int)
df['year']=df['year'].astype(int)
df['Temperature']=df['Temperature'].astype(int)
df['RH']=df['RH'].astype(int)
df['Ws']=df['Ws'].astype(float)
df['Rain']=df['Rain'].astype(float)
df['FFMC']=df['FFMC'].astype(float)
df['DMC']=df['DMC'].astype(float)
df['DC']=df['DC'].astype(float)
df['ISI']=df['ISI'].astype(float)
df['BUI']=df['BUI'].astype(float)
df['FWI']=df['FWI'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  region       243 non-null    float64
# dtypes: float64(9), int32(5), object(1)
# memory usage: 23.9+ KB

# %%
# Removing right space from classes
df['Classes'] = df['Classes'].str.rstrip()

# %% [markdown]
# #### Classes having string value notfire and fire changing to 0 and 1.

# %%
df['Classes']=df['Classes'].map({'notfire':0,'fire':1})

# %%
df.sample(10)
# Out:
#      day  month  year  Temperature  RH    Ws  Rain  FFMC   DMC     DC   ISI  \
# 111   20      9  2012           28  84  18.0   0.0  83.8  13.5   49.3   4.5
# 207   26      8  2012           33  37  16.0   0.0  92.2  61.3  167.2  13.1
# 46    17      7  2012           29  70  14.0   0.0  82.8   9.4   34.1   3.2
# 90    30      8  2012           35  70  17.0   0.8  72.7  25.2  180.4   1.7
# 135   14      6  2012           27  79  16.0   0.7  53.4   6.4    7.3   0.5
# 24    25      6  2012           31  64  15.0   0.0  86.7  14.2   63.8   5.7
# 47    18      7  2012           31  68  14.0   0.0  85.4  12.1   43.1   4.6
# 15    16      6  2012           29  89  13.0   0.7  36.1   1.7    7.6   0.0
# 86    26      8  2012           31  78  18.0   0.0  85.8  45.6  190.6   4.7
# 123    2      6  2012           30  73  13.0   4.0  55.7   2.7    7.8   0.6
#
#       BUI   FWI  Classes  region
# 111  16.0   6.3        1     0.0
# 207  64.0  30.3        1     1.0
# ...

# %% [markdown]
# ##### All Row value are in string

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%  \
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    int64
#  14  region       243 non-null    float64
# dtypes: float64(9), int32(5), int64(1)
# memory usage: 23.9 KB

# %%
df.drop('year',axis = 1, inplace = True)

# %% [markdown]
# ### Exploatry

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of all Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(df.columns)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[df.columns[i]],shade=True, color='b')
    plt.xlabel(df.columns[i])
    plt.tight_layout()

# %% [markdown]
# #### Report :- Rain, DMC, DC, ISI, BUI, FWI are Right Skewed and FFMC is left skewed

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

for i in range(0, len(df.columns)):
    plt.subplot(5, 3, i+1)
    sns.histplot(x=df[df.columns[i]])
    plt.xlabel(df.columns[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

for i in range(0, len(df.columns)):
    plt.subplot(5, 3, i+1)
    sns.boxplot(x=df[df.columns[i]])
    plt.xlabel(df.columns[i])
    plt.tight_layout()

# %% [markdown]
# #### Outliers are available in  WS, Rain, FFMC, DMC, DC, ISI, BUI, FWI .

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
sns.barplot(x=df['month'], y=df['Temperature'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='Temperature'>

# %% [markdown]
# #### Report
# In August Month temperature is high

# %%
sns.barplot(x=df['Temperature'], y=df['RH'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='RH'>

# %% [markdown]
# #### Report
# RH : Relative Humidity in %: 21 to 90
#
# If Temperature is increasing RH is decreasing

# %%
sns.barplot(x=df['month'], y=df['Rain'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='Rain'>

# %% [markdown]
# #### September month having huge rain

# %%
sns.barplot(x=df['Temperature'], y=df['Rain'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Rain'>

# %% [markdown]
# #### At 22 degree Temperature huge raining

# %%
sns.barplot(x=df['Classes'], y=df['Rain'])
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='Rain'>

# %% [markdown]
# #### Very Less rain while classes having 1(Fire)

# %%
sns.barplot(x=df['month'], y=df['DMC'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='DMC'>

# %% [markdown]
# #### Duff Moisture code in high in August month and low in September

# %%
sns.barplot(x=df['Classes'], y=df['DMC'])
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='DMC'>

# %% [markdown]
# #### Duff Moisture Code is high while classes are fire

# %%
sns.barplot(x=df['Classes'], y=df['ISI'])
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='ISI'>

# %% [markdown]
# #### Initial Spread Index value lies between 0 to 18.5, which is high in fire and low in not fire

# %%
sns.barplot(x=df['Classes'], y=df['BUI'])
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='BUI'>

# %% [markdown]
# #### Buildup Index is low in not fire and high count in fire

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Bivariate Analysis of Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)

for i in range(0, len(df.columns)):
    plt.subplot(5, 3, i+1)
    sns.barplot(x=df['Temperature'], y=df[df.columns[i]])
    plt.xlabel('Temperature')
    plt.tight_layout()

# %% [markdown]
# #### If Temperature is increasing RH value is decreasing and ISI value is increasing

# %% [markdown]
# ## Multivariate Analysis
#
# Multivariate analysis is the analysis of more than one variable.
#
# #### Check Multicollinearity in Numerical features

# %%
df[(list(df.columns)[1:])].corr()
# Out:
#                 month  Temperature        RH        Ws      Rain      FFMC  \
# month        1.000000    -0.056781 -0.041252 -0.039880  0.034822  0.017030
# Temperature -0.056781     1.000000 -0.651400 -0.284510 -0.326492  0.676568
# RH          -0.041252    -0.651400  1.000000  0.244048  0.222356 -0.644873
# Ws          -0.039880    -0.284510  0.244048  1.000000  0.171506 -0.166548
# Rain         0.034822    -0.326492  0.222356  0.171506  1.000000 -0.543906
# FFMC         0.017030     0.676568 -0.644873 -0.166548 -0.543906  1.000000
# DMC          0.067943     0.485687 -0.408519 -0.000721 -0.288773  0.603608
# DC           0.126511     0.376284 -0.226941  0.079135 -0.298023  0.507397
# ISI          0.065608     0.603871 -0.686667  0.008532 -0.347484  0.740007
# BUI          0.085073     0.459789 -0.353841  0.031438 -0.299852  0.592011
# FWI          0.082639     0.566670 -0.580957  0.032368 -0.324422  0.691132
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), cmap="CMRmap", annot=True)
plt.show()

# %% [markdown]
# #### Report
# BUI & DMC is highly correleted by 98%

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Boxplot Analysis of Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Drought Code (DC) index have more outliers

# %%
def outliers_imputation_mild(df,column):
    IQR=df[column].quantile(0.75)-df[column].quantile(0.25)
    lower_fence=df[column].quantile(0.25)-(IQR*1.5)
    upper_fence=df[column].quantile(0.75)+(IQR*1.5)
    df.loc[df[column]<=lower_fence,column]=lower_fence
    df.loc[df[column]>=upper_fence,column]=upper_fence 
columns = df.columns

# %%
outliers_imputation_mild(df,'DC')

# %%
outliers_imputation_mild(df,'BUI')

# %%
outliers_imputation_mild(df,'DMC')

# %%
outliers_imputation_mild(df,'FFMC')

# %%
outliers_imputation_mild(df,'FWI')

# %%
outliers_imputation_mild(df,'Ws')

# %% [markdown]
# #### Removed DC Outlier by IQR

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Boxplot Analysis of Features', fontsize=20, fontweight='bold', alpha=0.9, y=1.)
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(columns=['Classes'])
y=df['Classes']

# %% [markdown]
# #### Seperated x and y value

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.25, random_state=10)

# %% [markdown]
# Taken 25% of data for test and 75 % of dataset for Training model

# %%
## Standardize or feature scaling the datasets
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# #### Scaled training and test data, and creating linear regression object and traning with train dataset

# %%
logistic_regression=LogisticRegression()

# %%
logistic_regression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### After trainining predicted all test value

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
# r2 score
logistic_regression.score(x_train,y_train)
# Out:
# 0.989010989010989

# %% [markdown]
# ### Our model Training score is 98%

# %%
# Let's use the handy function we created
def adj_r2(x,y,r2):
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
# adj_r2 score

adj_r2(x_train,y_train,logistic_regression.score(x_train,y_train))
# Out:
# 0.9881606488749346

# %% [markdown]
# Great, our adjusted r2 score is almost same as r2 score, thus we are not being penalized for use of many features.

# %%
y_pred=logistic_regression.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9016393442622951

# %% [markdown]
# ### Test Score 90%

# %%
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[23,  0],
#        [ 6, 32]], dtype=int64)

# %%
true_positive = conf_mat[0][0]
false_positive = conf_mat[0][1]
false_negative = conf_mat[1][0]
true_negative = conf_mat[1][1]

# %%
Accuracy = (true_positive + true_negative) / (true_positive +false_positive + false_negative + true_negative)
Accuracy
# Out:
# 0.9016393442622951

# %%
Precision = true_positive/(true_positive+false_positive)
Precision
# Out:
# 1.0

# %%
Recall = true_positive/(true_positive+false_negative)
Recall
# Out:
# 0.7931034482758621

# %%
F1_Score = 2*(Recall * Precision) / (Recall + Precision)
F1_Score
# Out:
# 0.8846153846153846

# %%
auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.9210526315789473

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC curve (area = %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
